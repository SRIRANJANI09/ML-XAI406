# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
GA=pd.read_csv('C:/Users/Admin/Documents/SEM 4 ML(sri)/Admission_Predict.csv')

# %%
GA
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#     Research  Chance of Admit
# ...

# %%
GA.shape
# Out:
# (400, 9)

# %%
GA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    object
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.2+ KB

# %%
newdataset=GA.drop(['Serial No.','TOEFL Score','University Rating','SOP','LOR ' ,'CGPA','Research',],axis=1)

# %%
newdataset
# Out:
#      GRE Score  Chance of Admit
# 0          337              0.92
# 1          324              0.76
# 2          316              0.72
# 3          322              0.80
# 4          314              0.65
# ..         ...               ...
# 395        324              0.82
# 396        325              0.84
# 397        330              0.91
# 398        312              0.67
# 399        333              0.95
#
# [400 rows x 2 columns]

# %%
x=newdataset.iloc[:,0].values.reshape(-1,1)
y=newdataset.iloc[:,1].values.reshape(-1,1)

# %%
pt.scatter(x,y)
pt.xlabel('GRE SCORE')
pt.ylabel('CHA')
pt.title('linear reg')
pt.show()

# %%
pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=0)

# %%
x_train.shape
# Out:
# (320, 1)

# %%
y_train.shape
# Out:
# (320, 1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.8,random_state=0)

# %%
y_test
# Out:
# array([[0.71],
#        [0.7 ],
#        [0.79],
#        [0.73],
#        [0.72],
#        [0.48],
#        [0.77],
#        [0.71],
#        [0.9 ],
#        [0.94],
#        [0.58],
#        [0.89],
#        [0.72],
#        [0.57],
#        [0.78],
#        [0.42],
#        [0.64],
#        [0.84],
#        [0.63],
#        [0.72],
#        [0.9 ],
#        [0.83],
#        [0.57],
#        [0.47],
#        [0.85],
#        [0.67],
#        [0.44],
#        [0.54],
#        [0.92],
#        [0.62],
#        [0.68],
#        [0.73],
#        [0.73],
#        [0.61],
#        [0.55],
#        [0.74],
#        [0.64],
#        [0.89],
#        [0.73],
#        [0.95],
#        [0.71],
#        [0.72],
#        [0.75],
#        [0.76],
#        [0.86],
#        [0.7 ],
#        [0.39],
#        [0.79],
#        [0.61],
#        [0.64],
#        [0.71],
#        [0.8 ],
#        [0.61],
#        [0.89],
#        [0.68],
#        [0.79],
#        [0.78],
#        [0.52],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(x_test)

# %%
y_predict
# Out:
# array([[0.63541758],
#        [0.62479805],
#        [0.81594959],
#        [0.60355899],
#        [0.70975429],
#        [0.63541758],
#        [0.66727617],
#        [0.66727617],
#        [0.87966677],
#        [0.86904724],
#        [0.53984181],
#        [0.8902863 ],
#        [0.75223241],
#        [0.56108087],
#        [0.83718865],
#        [0.65665664],
#        [0.66727617],
#        [0.84780818],
#        [0.69913476],
#        [0.6778957 ],
#        [0.84780818],
#        [0.82656912],
#        [0.55046134],
#        [0.48674416],
#        [0.75223241],
#        [0.55046134],
#        [0.49736369],
#        [0.68851523],
#        [0.92214489],
#        [0.68851523],
#        [0.66727617],
#        [0.784091  ],
#        [0.66727617],
#        [0.49736369],
#        [0.80533006],
#        [0.82656912],
#        [0.73099335],
#        [0.784091  ],
#        [0.61417852],
#        [0.8902863 ],
#        [0.77347147],
#        [0.68851523],
#        [0.76285194],
# ...

# %%
y_predict.shape
# Out:
# (320, 1)

# %%
COMP=pd.DataFrame(x_test,columns=["GRE"])

# %%
COMP
# Out:
#      GRE
# 0    309
# 1    308
# 2    326
# 3    306
# 4    316
# ..   ...
# 315  304
# 316  312
# 317  339
# 318  340
# 319  300
#
# [320 rows x 1 columns]

# %%
COMP['AVLDATA']=y_test

# %%
COMP
# Out:
#      GRE  AVLDATA
# 0    309     0.71
# 1    308     0.70
# 2    326     0.79
# 3    306     0.73
# 4    316     0.72
# ..   ...      ...
# 315  304     0.67
# 316  312     0.64
# 317  339     0.96
# 318  340     0.97
# 319  300     0.71
#
# [320 rows x 2 columns]

# %%
COMP['PRDDATA']=y_test

# %%
COMP
# Out:
#      GRE  AVLDATA  PRDDATA
# 0    309     0.71     0.71
# 1    308     0.70     0.70
# 2    326     0.79     0.79
# 3    306     0.73     0.73
# 4    316     0.72     0.72
# ..   ...      ...      ...
# 315  304     0.67     0.67
# 316  312     0.64     0.64
# 317  339     0.96     0.96
# 318  340     0.97     0.97
# 319  300     0.71     0.71
#
# [320 rows x 3 columns]

# %%
pt.scatter(x,y,color='cyan')
pt.plot(x_test,y_predict,color='black')
pt.xlabel('GRE SCORE')
pt.ylabel('CHA')
pt.title('linear reg')
pt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %% [markdown]
# the mean squared error measures how close a regression line is to set of data points

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 0.007259186523804116

# %% [raw]
# mean_absolute_error(MAE) is the avg variance btwn the significant values in the dataset and the projected values in the same project

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 0.06513853574550946

# %%
r2_score(y_test,y_predict)
# Out:
# 0.6232758197584529
