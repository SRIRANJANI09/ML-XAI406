# %% [markdown]
# # creating data

# %%
soc_med=['instagram','facebook','twitter','linkedin']
user=[20000,10000,2000,1000]

# %%
soc_med=dimension
user=measures

# %% [markdown]
# # importing libraries

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # scatter plot

# %%
plt.scatter(soc_med,user)

# %% [markdown]
# # lineplot

# %%
plt.plot(soc_med,user,linestyle="dotted")
#styles(dotted,solid,dashed)

# %% [markdown]
# # piechart

# %%
plt.pie(user,labels=soc_med)
3
# Out:
# ([<matplotlib.patches.Wedge at 0x28c3d1afcd0>,
# ...
#  [Text(-0.35977481863407124, 1.0395008801712586, 'instagram'),
#   Text(0.052340263273965786, -1.098754065676397, 'facebook'),
#   Text(1.0212047982326018, -0.40882852159152416, 'twitter'),
#   Text(1.095019134113251, -0.10456144569518265, 'linkedin')])

# %% [markdown]
# # barchat

# %%
plt.bar(soc_med,user)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # sine wave

# %%
sine wave-used to measures the voltage
x axis-time
yaxis -amplitude

# %%
import numpy as np

# %%
time=np.arange(0,100,0.05)

# %%
time
# Out:
# array([0.000e+00, 5.000e-02, 1.000e-01, ..., 9.985e+01, 9.990e+01,
#        9.995e+01])

# %%
amplitude =np.sin(time)

# %%
amplitude
# Out:
# array([ 0.        ,  0.04997917,  0.09983342, ..., -0.62954302,
#        -0.58992416, -0.5488308 ])

# %%
plt.plot(time,amplitude)
